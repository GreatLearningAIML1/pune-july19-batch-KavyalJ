# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np
iris = pd.read_csv('iris.csv')

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
iris.head(10)
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# 5                  0.4  Iris-setosa
# 6                  0.3  Iris-setosa
# 7                  0.2  Iris-setosa
# 8                  0.2  Iris-setosa
# 9                  0.1  Iris-setosa

# %%
iris.tail(10)
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 140                   6.7                  3.1                   5.6
# 141                   6.9                  3.1                   5.1
# 142                   5.8                  2.7                   5.1
# 143                   6.8                  3.2                   5.9
# 144                   6.7                  3.3                   5.7
# 145                   6.7                  3.0                   5.2
# 146                   6.3                  2.5                   5.0
# 147                   6.5                  3.0                   5.2
# 148                   6.2                  3.4                   5.4
# 149                   5.9                  3.0                   5.1
#
#      Petal width (in cm)           Class
# 140                  2.4  Iris-virginica
# 141                  2.3  Iris-virginica
# 142                  1.9  Iris-virginica
# 143                  2.3  Iris-virginica
# 144                  2.5  Iris-virginica
# 145                  2.3  Iris-virginica
# 146                  1.9  Iris-virginica
# 147                  2.0  Iris-virginica
# 148                  2.3  Iris-virginica
# 149                  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
#=iris[]
iris.index=iris.iloc[:,0]

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,2]
# Out:
# Sepal Length (in cm)
# 5.1    1.4
# 4.9    1.4
# 4.7    1.3
# 4.6    1.5
# 5.0    1.4
# 5.4    1.7
# 4.6    1.4
# 5.0    1.5
# 4.4    1.4
# 4.9    1.5
# 5.4    1.5
# 4.8    1.6
# 4.8    1.4
# 4.3    1.1
# 5.8    1.2
# 5.7    1.5
# 5.4    1.3
# 5.1    1.4
# 5.7    1.7
# 5.1    1.5
# 5.4    1.7
# 5.1    1.5
# 4.6    1.0
# 5.1    1.7
# 4.8    1.9
# 5.0    1.6
# 5.0    1.6
# 5.2    1.5
# 5.2    1.4
# 4.7    1.6
#       ...
# 6.9    5.7
# 5.6    4.9
# 7.7    6.7
# 6.3    4.9
# 6.7    5.7
# 7.2    6.0
# 6.2    4.8
# 6.1    4.9
# 6.4    5.6
# 7.2    5.8
# 7.4    6.1
# 7.9    6.4
# 6.4    5.6
# 6.3    5.1
# 6.1    5.6
# 7.7    6.1
# 6.3    5.6
# 6.4    5.5
# 6.0    4.8
# 6.9    5.4
# 6.7    5.6
# 6.9    5.1
# 5.8    5.1
# 6.8    5.9
# 6.7    5.7
# 6.7    5.2
# 6.3    5.0
# 6.5    5.2
# 6.2    5.4
# 5.9    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[0:9,[0,1]]
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
df=iris.loc[iris['Class']=="Iris-setosa"]
df.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra']=iris['Sepal Length (in cm)']*iris['Sepal Width in (cm)']

# %%
iris.head()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
#
#                       Petal length (in cm)  Petal width (in cm)        Class  \
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2  Iris-setosa
# 4.9                                    1.4                  0.2  Iris-setosa
# 4.7                                    1.3                  0.2  Iris-setosa
# 4.6                                    1.5                  0.2  Iris-setosa
# 5.0                                    1.4                  0.2  Iris-setosa
#
#                       SepalExtra
# Sepal Length (in cm)
# 5.1                        17.85
# 4.9                        14.70
# 4.7                        15.04
# 4.6                        14.26
# 5.0                        18.00

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.mean(axis=0)
# Out:
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %%
iris.var(axis=0)
# Out:
# Sepal Length (in cm)     0.685694
# Sepal Width in (cm)      0.188004
# Petal length (in cm)     3.113179
# Petal width (in cm)      0.582414
# SepalExtra              11.348090
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def printInput(num1, num2):
    print(num1)
    print(num2)

# %%
printInput(iris.iloc[4,0],iris.iloc[4,1])
# Out:
# 5.0
# 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
Range = lambda col : col.max() - col.min() if col.dtype!=object else print('column dtype is a string')
print(Range(iris['Sepal Length (in cm)']))
print(Range(iris['Sepal Width in (cm)']))
print(Range(iris['Petal length (in cm)']))
print(Range(iris['Petal width (in cm)']))
print(Range(iris['SepalExtra']))
#Range(iris['Class'])

#iris['Sepal Length (in cm)'].max()-iris['Sepal Length (in cm)'].min()
# Out:
# 3.6000000000000005
# 2.4000000000000004
# 5.9
# 2.4
# 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris.sort_values(by=['Petal length (in cm)'])
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 4.6                                    4.6                  3.6
# 4.3                                    4.3                  3.0
# 5.8                                    5.8                  4.0
# 5.0                                    5.0                  3.2
# 5.5                                    5.5                  3.5
# 5.0                                    5.0                  3.5
# 4.4                                    4.4                  3.0
# 4.4                                    4.4                  3.2
# 4.7                                    4.7                  3.2
# 4.5                                    4.5                  2.3
# 5.4                                    5.4                  3.9
# 5.1                                    5.1                  3.5
# 4.8                                    4.8                  3.0
# 5.5                                    5.5                  4.2
# 5.2                                    5.2                  3.4
# 4.6                                    4.6                  3.2
# 5.0                                    5.0                  3.3
# 5.1                                    5.1                  3.5
# 5.0                                    5.0                  3.6
# 4.9                                    4.9                  3.0
# 4.8                                    4.8                  3.0
# 4.6                                    4.6                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
# 5.4                                    5.4                  3.7
# 5.2                                    5.2                  4.1
# 5.4                                    5.4                  3.4
# 5.7                                    5.7                  4.4
# 5.2                                    5.2                  3.5
# 4.9                                    4.9                  3.1
# ...                                    ...                  ...
# 6.9                                    6.9                  3.1
# 6.2                                    6.2                  3.4
# 6.4                                    6.4                  3.1
# 6.8                                    6.8                  3.0
# 6.5                                    6.5                  3.0
# 6.3                                    6.3                  3.4
# 6.7                                    6.7                  3.1
# 6.4                                    6.4                  2.8
# 6.1                                    6.1                  2.6
# 6.3                                    6.3                  2.9
# 6.4                                    6.4                  2.8
# 6.7                                    6.7                  3.3
# 6.9                                    6.9                  3.2
# 6.7                                    6.7                  3.3
# 6.7                                    6.7                  2.5
# 7.2                                    7.2                  3.0
# 6.5                                    6.5                  3.0
# 7.1                                    7.1                  3.0
# 6.8                                    6.8                  3.2
# 6.3                                    6.3                  3.3
# 7.2                                    7.2                  3.2
# 7.4                                    7.4                  2.8
# 7.7                                    7.7                  3.0
# 7.2                                    7.2                  3.6
# 7.3                                    7.3                  2.9
# 7.9                                    7.9                  3.8
# 7.6                                    7.6                  3.0
# 7.7                                    7.7                  3.8
# 7.7                                    7.7                  2.8
# 7.7                                    7.7                  2.6
#
#                       Petal length (in cm)  Petal width (in cm)  SepalExtra
# Sepal Length (in cm)
# 4.6                                    1.0                  0.2       16.56
# 4.3                                    1.1                  0.1       12.90
# 5.8                                    1.2                  0.2       23.20
# 5.0                                    1.2                  0.2       16.00
# 5.5                                    1.3                  0.2       19.25
# 5.0                                    1.3                  0.3       17.50
# 4.4                                    1.3                  0.2       13.20
# 4.4                                    1.3                  0.2       14.08
# 4.7                                    1.3                  0.2       15.04
# 4.5                                    1.3                  0.3       10.35
# 5.4                                    1.3                  0.4       21.06
# 5.1                                    1.4                  0.3       17.85
# 4.8                                    1.4                  0.3       14.40
# 5.5                                    1.4                  0.2       23.10
# 5.2                                    1.4                  0.2       17.68
# 4.6                                    1.4                  0.2       14.72
# 5.0                                    1.4                  0.2       16.50
# 5.1                                    1.4                  0.2       17.85
# 5.0                                    1.4                  0.2       18.00
# 4.9                                    1.4                  0.2       14.70
# 4.8                                    1.4                  0.1       14.40
# 4.6                                    1.4                  0.3       15.64
# 4.4                                    1.4                  0.2       12.76
# 4.9                                    1.5                  0.1       15.19
# 5.4                                    1.5                  0.2       19.98
# 5.2                                    1.5                  0.1       21.32
# 5.4                                    1.5                  0.4       18.36
# 5.7                                    1.5                  0.4       25.08
# 5.2                                    1.5                  0.2       18.20
# 4.9                                    1.5                  0.1       15.19
# ...                                    ...                  ...         ...
# 6.9                                    5.4                  2.1       21.39
# 6.2                                    5.4                  2.3       21.08
# 6.4                                    5.5                  1.8       19.84
# 6.8                                    5.5                  2.1       20.40
# 6.5                                    5.5                  1.8       19.50
# 6.3                                    5.6                  2.4       21.42
# 6.7                                    5.6                  2.4       20.77
# 6.4                                    5.6                  2.1       17.92
# 6.1                                    5.6                  1.4       15.86
# 6.3                                    5.6                  1.8       18.27
# 6.4                                    5.6                  2.2       17.92
# 6.7                                    5.7                  2.5       22.11
# 6.9                                    5.7                  2.3       22.08
# 6.7                                    5.7                  2.1       22.11
# 6.7                                    5.8                  1.8       16.75
# 7.2                                    5.8                  1.6       21.60
# 6.5                                    5.8                  2.2       19.50
# 7.1                                    5.9                  2.1       21.30
# 6.8                                    5.9                  2.3       21.76
# 6.3                                    6.0                  2.5       20.79
# 7.2                                    6.0                  1.8       23.04
# 7.4                                    6.1                  1.9       20.72
# 7.7                                    6.1                  2.3       23.10
# 7.2                                    6.1                  2.5       25.92
# 7.3                                    6.3                  1.8       21.17
# 7.9                                    6.4                  2.0       30.02
# 7.6                                    6.6                  2.1       22.80
# 7.7                                    6.7                  2.2       29.26
# 7.7                                    6.7                  2.0       21.56
# 7.7                                    6.9                  2.3       20.02
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris.drop(labels=['SepalExtra'],axis=1)
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)
# 5.1                                    5.1                  3.5
# 4.9                                    4.9                  3.0
# 4.7                                    4.7                  3.2
# 4.6                                    4.6                  3.1
# 5.0                                    5.0                  3.6
# 5.4                                    5.4                  3.9
# 4.6                                    4.6                  3.4
# 5.0                                    5.0                  3.4
# 4.4                                    4.4                  2.9
# 4.9                                    4.9                  3.1
# 5.4                                    5.4                  3.7
# 4.8                                    4.8                  3.4
# 4.8                                    4.8                  3.0
# 4.3                                    4.3                  3.0
# 5.8                                    5.8                  4.0
# 5.7                                    5.7                  4.4
# 5.4                                    5.4                  3.9
# 5.1                                    5.1                  3.5
# 5.7                                    5.7                  3.8
# 5.1                                    5.1                  3.8
# 5.4                                    5.4                  3.4
# 5.1                                    5.1                  3.7
# 4.6                                    4.6                  3.6
# 5.1                                    5.1                  3.3
# 4.8                                    4.8                  3.4
# 5.0                                    5.0                  3.0
# 5.0                                    5.0                  3.4
# 5.2                                    5.2                  3.5
# 5.2                                    5.2                  3.4
# 4.7                                    4.7                  3.2
# ...                                    ...                  ...
# 6.9                                    6.9                  3.2
# 5.6                                    5.6                  2.8
# 7.7                                    7.7                  2.8
# 6.3                                    6.3                  2.7
# 6.7                                    6.7                  3.3
# 7.2                                    7.2                  3.2
# 6.2                                    6.2                  2.8
# 6.1                                    6.1                  3.0
# 6.4                                    6.4                  2.8
# 7.2                                    7.2                  3.0
# 7.4                                    7.4                  2.8
# 7.9                                    7.9                  3.8
# 6.4                                    6.4                  2.8
# 6.3                                    6.3                  2.8
# 6.1                                    6.1                  2.6
# 7.7                                    7.7                  3.0
# 6.3                                    6.3                  3.4
# 6.4                                    6.4                  3.1
# 6.0                                    6.0                  3.0
# 6.9                                    6.9                  3.1
# 6.7                                    6.7                  3.1
# 6.9                                    6.9                  3.1
# 5.8                                    5.8                  2.7
# 6.8                                    6.8                  3.2
# 6.7                                    6.7                  3.3
# 6.7                                    6.7                  3.0
# 6.3                                    6.3                  2.5
# 6.5                                    6.5                  3.0
# 6.2                                    6.2                  3.4
# 5.9                                    5.9                  3.0
#
#                       Petal length (in cm)  Petal width (in cm)
# Sepal Length (in cm)
# 5.1                                    1.4                  0.2
# 4.9                                    1.4                  0.2
# 4.7                                    1.3                  0.2
# 4.6                                    1.5                  0.2
# 5.0                                    1.4                  0.2
# 5.4                                    1.7                  0.4
# 4.6                                    1.4                  0.3
# 5.0                                    1.5                  0.2
# 4.4                                    1.4                  0.2
# 4.9                                    1.5                  0.1
# 5.4                                    1.5                  0.2
# 4.8                                    1.6                  0.2
# 4.8                                    1.4                  0.1
# 4.3                                    1.1                  0.1
# 5.8                                    1.2                  0.2
# 5.7                                    1.5                  0.4
# 5.4                                    1.3                  0.4
# 5.1                                    1.4                  0.3
# 5.7                                    1.7                  0.3
# 5.1                                    1.5                  0.3
# 5.4                                    1.7                  0.2
# 5.1                                    1.5                  0.4
# 4.6                                    1.0                  0.2
# 5.1                                    1.7                  0.5
# 4.8                                    1.9                  0.2
# 5.0                                    1.6                  0.2
# 5.0                                    1.6                  0.4
# 5.2                                    1.5                  0.2
# 5.2                                    1.4                  0.2
# 4.7                                    1.6                  0.2
# ...                                    ...                  ...
# 6.9                                    5.7                  2.3
# 5.6                                    4.9                  2.0
# 7.7                                    6.7                  2.0
# 6.3                                    4.9                  1.8
# 6.7                                    5.7                  2.1
# 7.2                                    6.0                  1.8
# 6.2                                    4.8                  1.8
# 6.1                                    4.9                  1.8
# 6.4                                    5.6                  2.1
# 7.2                                    5.8                  1.6
# 7.4                                    6.1                  1.9
# 7.9                                    6.4                  2.0
# 6.4                                    5.6                  2.2
# 6.3                                    5.1                  1.5
# 6.1                                    5.6                  1.4
# 7.7                                    6.1                  2.3
# 6.3                                    5.6                  2.4
# 6.4                                    5.5                  1.8
# 6.0                                    4.8                  1.8
# 6.9                                    5.4                  2.1
# 6.7                                    5.6                  2.4
# 6.9                                    5.1                  2.3
# 5.8                                    5.1                  1.9
# 6.8                                    5.9                  2.3
# 6.7                                    5.7                  2.5
# 6.7                                    5.2                  2.3
# 6.3                                    5.0                  1.9
# 6.5                                    5.2                  2.0
# 6.2                                    5.4                  2.3
# 5.9                                    5.1                  1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris.iloc[0:9,0:2]

# %% [raw]
# IrisSubset

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
hr = pd.read_csv('HR_external.txt', sep='\t')

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
hr.shape
# Out:
# (1470, 35)

# %%
hr.head(2)
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0        Ind1       Yes   41               1       1102           1
# 1        Ind2        No   49               2        279           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
hr.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
hr.iloc[:,2:9]
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# 10     35               1        809           2                16          3
# 11     29               1        153           2                15          2
# 12     31               1        670           2                26          1
# 13     34               1       1346           2                19          2
# 14     28               1        103           2                24          3
# 15     29               1       1389           2                21          4
# 16     32               1        334           2                 5          2
# 17     22               3       1123           2                16          2
# 18     53               1       1219           1                 2          4
# 19     38               1        371           2                 2          3
# 20     24               3        673           2                11          2
# 21     36               1       1218           1                 9          4
# 22     34               1        419           2                 7          4
# 23     21               1        391           2                15          2
# 24     34               1        699           2                 6          1
# 25     53               1       1282           2                 5          3
# 26     32               2       1125           2                16          1
# 27     42               1        691           1                 8          4
# 28     44               1        477           2                 7          4
# 29     46               1        705           1                 2          4
# ...   ...             ...        ...         ...               ...        ...
# 1440   36               2        688           2                 4          2
# 1441   56               3        667           2                 1          4
# 1442   29               1       1092           2                 1          4
# 1443   42               1        300           2                 2          3
# 1444   56               1        310           2                 7          2
# 1445   41               1        582           2                28          4
# 1446   34               1        704           1                28          3
# 1447   36               3        301           1                15          4
# 1448   41               1        930           1                 3          3
# 1449   32               1        529           2                 2          3
# 1450   35               1       1146           3                26          4
# 1451   38               1        345           1                10          2
# 1452   50               2        878           1                 1          4
# 1453   36               1       1120           1                11          4
# 1454   45               1        374           1                20          3
# 1455   40               1       1322           2                 2          4
# 1456   35               2       1199           2                18          4
# 1457   40               1       1194           2                 2          4
# 1458   35               1        287           2                 1          4
# 1459   29               1       1378           2                13          2
# 1460   29               1        468           2                28          4
# 1461   50               1        410           1                28          3
# 1462   39               1        722           1                24          1
# 1463   31               3        325           2                 5          3
# 1464   26               1       1167           1                 5          3
# 1465   36               2        884           2                23          2
# 1466   39               1        613           2                 6          1
# 1467   27               1        155           2                 4          3
# 1468   49               2       1023           1                 2          3
# 1469   34               1        628           2                 8          3
#
#       EducationField
# 0                  1
# 1                  1
# 2                  6
# 3                  1
# 4                  2
# 5                  1
# 6                  2
# 7                  1
# 8                  1
# 9                  2
# 10                 2
# 11                 1
# 12                 1
# 13                 2
# 14                 1
# 15                 1
# 16                 1
# 17                 2
# 18                 1
# 19                 1
# 20                 6
# 21                 1
# 22                 1
# 23                 1
# 24                 2
# 25                 6
# 26                 1
# 27                 3
# 28                 2
# 29                 3
# ...              ...
# 1440               1
# 1441               1
# 1442               2
# 1443               1
# 1444               4
# 1445               1
# 1446               3
# 1447               3
# 1448               1
# 1449               4
# 1450               1
# 1451               1
# 1452               1
# 1453               3
# 1454               1
# 1455               1
# 1456               1
# 1457               2
# 1458               1
# 1459               6
# 1460               2
# 1461               3
# 1462               3
# 1463               2
# 1464               6
# 1465               2
# 1466               2
# 1467               1
# 1468               2
# 1469               2
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
hr['Gender']  #males as 1 females as 2
males_n=hr.loc[hr['Gender']==1]
females_n=hr.loc[hr['Gender']==2]

females_n.head()
# Out:
#    Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0         Ind1       Yes   41               1       1102           1
# 3         Ind4        No   33               2       1392           2
# 6         Ind7        No   59               1       1324           2
# 11       Ind12        No   29               1        153           2
# 15       Ind16        No   29               1       1389           2
#
#     DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                  1          2               1              1  ...
# 3                  3          4               1              1  ...
# 6                  3          3               2              1  ...
# 11                15          2               1              1  ...
# 15                21          4               1              1  ...
#
#     RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                          1             80                 0
# 3                          3             80                 0
# 6                          1             80                 3
# 11                         4             80                 0
# 15                         3             80                 1
#
#     TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                   8                      0                1               6
# 3                   8                      3                3               8
# 6                  12                      3                2               1
# 11                 10                      3                3               9
# 15                 10                      1                3              10
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                    4                        0                     5
# 3                    7                        3                     0
# 6                    0                        0                     0
# 11                   5                        0                     8
# 15                   9                        8                     8
#
# [5 rows x 35 columns]

# %%
males_n.head()
# Out:
#   Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 1        Ind2        No   49               2        279           2
# 2        Ind3       Yes   37               1       1373           2
# 4        Ind5        No   27               1        591           2
# 5        Ind6        No   32               2       1005           2
# 7        Ind8        No   30               1       1358           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 4                 2          1               2              1  ...
# 5                 2          2               1              1  ...
# 7                24          1               1              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 1                         4             80                 1
# 2                         2             80                 0
# 4                         4             80                 1
# 5                         3             80                 0
# 7                         2             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 4                  6                      3                3               2
# 5                  8                      2                2               7
# 7                  1                      2                3               1
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 1                   7                        1                     7
# 2                   0                        0                     0
# 4                   2                        2                     2
# 5                   7                        3                     6
# 7                   0                        0                     0
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
hr['Age'].quantile(q=0.75)-hr['Age'].quantile(q=0.25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
print(hr['DailyRate'].mean())
print(hr['DailyRate'].median())
print(hr['DailyRate'].var())
# Out:
# 802.4857142857143
# 802.0
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="Attrition", data=hr)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
plt.plot('TotalWorkingYears',scalex=True, scaley=True, data=hr)#this plot makes no sense to me and I don't know how to make it legible hence I am making a boxplot below
rcParams["figure.figsize"] = 20, 8

# %%
sns.boxplot(x=hr['TotalWorkingYears'])
